# %% [markdown]
# # Demonstrate use of functions.py
#
# Note: the conda environment py36isa can be created as described here: https://gist.github.com/niehues/2e968e222489692f281d8361045766b0

# %%
# import functions from functions.py
import sys
sys.path.append(".")
from functions import *

# %% [markdown]
# ## Read metataxonomics data file

# %%
metataxonomics_feature_data = "/Users/christelvanharen/Documents/StageRadboud/isatools/TWOCdemonstrator/data/ISA_test/feature-matrices-general.csv"
df = read_omics_data(metataxonomics_feature_data)
print(df.shape)
df.iloc[:4,:5]
# Out:
# (215, 122)
#                              sample028  sample031  sample041  sample043  \
# feature.name
# Bacteroides                      31.11      25.63      33.12      21.17
# Prevotella                        0.00       0.24       0.00       0.00
# Prevotellaceae_NK3B31_group       0.00       0.00       0.00       0.00
# Paraprevotella                    0.00       0.00       0.00       0.00
#
#                              sample044
# feature.name
# Bacteroides                      28.04
# Prevotella                        0.00
# Prevotellaceae_NK3B31_group       0.00
# Paraprevotella                    0.00

# %% [markdown]
# ## Read metabolomics feature metadata file

# %%
metataxonomics_feature_metadata_path = "/Users/christelvanharen/Documents/StageRadboud/isatools/TWOCdemonstrator/data/ISA_test/metataxonomics-fmeta.csv"
metataxonomics_feature_metadata = read_omics_data(metataxonomics_feature_metadata_path)
print(metataxonomics_feature_metadata.shape)
metataxonomics_feature_metadata
# Out:
# (215, 3)
#                                              database.ID  \
# feature.name
# Bacteroides                                  Bacteroides
# Prevotella                                    Prevotella
# Prevotellaceae_NK3B31_group  Prevotellaceae_NK3B31_group
# Paraprevotella                            Paraprevotella
# Alloprevotella                            Alloprevotella
# ...                                                  ...
# Sneathia                                        Sneathia
# Leptotrichia                                Leptotrichia
# Cloacibacillus                            Cloacibacillus
# Pyramidobacter                            Pyramidobacter
# Fretibacterium                            Fretibacterium
#
#                                               database database.version
# feature.name
# Bacteroides                  https://www.arb-silva.de/      release-138
# Prevotella                   https://www.arb-silva.de/      release-138
# Prevotellaceae_NK3B31_group  https://www.arb-silva.de/      release-138
# Paraprevotella               https://www.arb-silva.de/      release-138
# Alloprevotella               https://www.arb-silva.de/      release-138
# ...                                                ...              ...
# Sneathia                     https://www.arb-silva.de/      release-138
# Leptotrichia                 https://www.arb-silva.de/      release-138
# Cloacibacillus               https://www.arb-silva.de/      release-138
# Pyramidobacter               https://www.arb-silva.de/      release-138
# Fretibacterium               https://www.arb-silva.de/      release-138
#
# [215 rows x 3 columns]

# %% [markdown]
# ## Create column with feature PID's

# %%
create_feature_PID(metataxonomics_feature_metadata)
# Out:
#                                              database.ID  \
# feature.name
# Bacteroides                                  Bacteroides
# Prevotella                                    Prevotella
# Prevotellaceae_NK3B31_group  Prevotellaceae_NK3B31_group
# Paraprevotella                            Paraprevotella
# Alloprevotella                            Alloprevotella
# ...                                                  ...
# Sneathia                                        Sneathia
# Leptotrichia                                Leptotrichia
# Cloacibacillus                            Cloacibacillus
# Pyramidobacter                            Pyramidobacter
# Fretibacterium                            Fretibacterium
#
#                                               database database.version  \
# feature.name
# Bacteroides                  https://www.arb-silva.de/      release-138
# Prevotella                   https://www.arb-silva.de/      release-138
# Prevotellaceae_NK3B31_group  https://www.arb-silva.de/      release-138
# Paraprevotella               https://www.arb-silva.de/      release-138
# Alloprevotella               https://www.arb-silva.de/      release-138
# ...                                                ...              ...
# Sneathia                     https://www.arb-silva.de/      release-138
# Leptotrichia                 https://www.arb-silva.de/      release-138
# Cloacibacillus               https://www.arb-silva.de/      release-138
# Pyramidobacter               https://www.arb-silva.de/      release-138
# Fretibacterium               https://www.arb-silva.de/      release-138
#
#                                                                            PID
# feature.name
# Bacteroides                               https://www.arb-silva.de/Bacteroides
# Prevotella                                 https://www.arb-silva.de/Prevotella
# Prevotellaceae_NK3B31_group  https://www.arb-silva.de/Prevotellaceae_NK3B31...
# Paraprevotella                         https://www.arb-silva.de/Paraprevotella
# Alloprevotella                         https://www.arb-silva.de/Alloprevotella
# ...                                                                        ...
# Sneathia                                     https://www.arb-silva.de/Sneathia
# Leptotrichia                             https://www.arb-silva.de/Leptotrichia
# Cloacibacillus                         https://www.arb-silva.de/Cloacibacillus
# Pyramidobacter                         https://www.arb-silva.de/Pyramidobacter
# Fretibacterium                         https://www.arb-silva.de/Fretibacterium
#
# [215 rows x 4 columns]

# %% [markdown]
# ## Subset omics data on features and/or sample IDs

# %%
features_list = ['Parasutterella', 'Barnesiella', '[Bacteroides]_pectinophilus_group', 'Peptococcus', 'Muribaculaceae', 'Lachnospiraceae_NK4A136_group', 'GCA-900066575', 'Roseburia', 'UCG-004',]
sample_list = ['sample197', 'sample058', 'sample098', 'sample083', 'sample195', 'sample056', 'sample066', 'sample128', 'sample190', 'sample186', 'sample141', 'sample164', 'sample052', 'sample078', 'sample121', 'sample158', 'sample198', 'sample048', 'sample105', 'sample163']

df_subset = subset_omics_data(df, features_list=features_list, sample_list=sample_list)
df_subset

# %% [markdown]
# ## Calculate mean for every feature

# %%
calculate_means(df_subset)
# Out:
# {'Muribaculaceae': 0.3715,
#  'Barnesiella': 0.2085,
#  'Lachnospiraceae_NK4A136_group': 0.4739999999999999,
#  'GCA-900066575': 0.020499999999999997,
#  '[Bacteroides]_pectinophilus_group': 0.0035000000000000005,
#  'Roseburia': 2.0885000000000002,
#  'Peptococcus': 0.008,
#  'UCG-004': 0.0035000000000000005,
#  'Parasutterella': 0.24500000000000002}
